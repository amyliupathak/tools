# %%
import pandas as pd
#import warnings
#warnings.filterwarnings(action='ignore')
# %cd C:\Users\Amy.LiuPathak\Python\PennX
# Out:
# C:\Users\Amy.LiuPathak\Python\PennX

# %%
jan_yellow = pd.read_parquet('data/yellow_tripdata_2022-01.parquet', engine='fastparquet')
jan_green = pd.read_parquet('data/green_tripdata_2022-01.parquet', engine='fastparquet')
jan_fhv = pd.read_parquet('data/fhv_tripdata_2022-01.parquet', engine='fastparquet')
jan_fhvhv = pd.read_parquet('data/fhvhv_tripdata_2022-01.parquet', engine='fastparquet')

# %%
list(jan_yellow.columns.values)
# Out:
# ['VendorID',
#  'tpep_pickup_datetime',
#  'tpep_dropoff_datetime',
#  'passenger_count',
#  'trip_distance',
#  'RatecodeID',
#  'store_and_fwd_flag',
#  'PULocationID',
#  'DOLocationID',
#  'payment_type',
#  'fare_amount',
#  'extra',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'improvement_surcharge',
#  'total_amount',
#  'congestion_surcharge',
#  'airport_fee']

# %%
list(jan_green.columns.values)
# Out:
# ['VendorID',
#  'tpep_pickup_datetime',
#  'tpep_dropoff_datetime',
#  'passenger_count',
#  'trip_distance',
#  'RatecodeID',
#  'store_and_fwd_flag',
#  'PULocationID',
#  'DOLocationID',
#  'payment_type',
#  'fare_amount',
#  'extra',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'improvement_surcharge',
#  'total_amount',
#  'congestion_surcharge',
#  'airport_fee']

# %%
list(jan_fhv.columns.values)
# Out:
# ['dispatching_base_num',
#  'pickup_datetime',
#  'dropOff_datetime',
#  'PUlocationID',
#  'DOlocationID',
#  'SR_Flag',
#  'Affiliated_base_number']

# %%
list(jan_fhvhv.columns.values)
# Out:
# ['hvfhs_license_num',
#  'dispatching_base_num',
#  'originating_base_num',
#  'request_datetime',
#  'on_scene_datetime',
#  'pickup_datetime',
#  'dropoff_datetime',
#  'PULocationID',
#  'DOLocationID',
#  'trip_miles',
#  'trip_time',
#  'base_passenger_fare',
#  'tolls',
#  'bcf',
#  'sales_tax',
#  'congestion_surcharge',
#  'airport_fee',
#  'tips',
#  'driver_pay',
#  'shared_request_flag',
#  'shared_match_flag',
#  'access_a_ride_flag',
#  'wav_request_flag',
#  'wav_match_flag']

# %%
jan_yellow_zones = jan_yellow[jan_yellow['PULocationID' or 'DOLocationID' ].isin([186,164,100])]
jan_yellow_zones
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 62              2  2022-01-01 00:29:45   2022-01-01 00:42:02              4.0
# 105             2  2022-01-01 00:09:50   2022-01-01 00:13:40              5.0
# 126             2  2022-01-01 00:54:54   2022-01-01 01:14:37              2.0
# 151             2  2022-01-01 00:10:42   2022-01-01 00:27:19              3.0
# 165             2  2022-01-01 00:31:05   2022-01-01 00:41:25              1.0
# ...           ...                  ...                   ...              ...
# 2463871         1  2022-01-31 23:25:54   2022-01-31 23:41:23              NaN
# 2463899         2  2022-01-31 23:31:00   2022-01-31 23:43:00              NaN
# 2463906         2  2022-01-31 23:40:00   2022-01-31 23:50:00              NaN
# 2463909         2  2022-01-31 23:21:08   2022-01-31 23:42:09              NaN
# 2463930         2  2022-01-31 23:46:00   2022-02-01 00:13:00              NaN
#
# ...

# %%
jan_green_zones = jan_green[jan_green['PULocationID' or 'DOLocationID' ].isin([186,164,100])]
jan_green_zones
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 27497         1  2022-01-15 22:42:52   2022-01-15 23:07:25                  Y
# 37975         1  2022-01-21 16:12:41   2022-01-21 17:04:50                  N
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 27497         1.0           186            74              1.0            0.0
# 37975         1.0           100           108              1.0            0.0
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 27497         28.2    0.0      0.5         0.0          0.00        NaN
# 37975         41.2    0.0      0.5         0.0          6.55        NaN
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 27497                    0.3         29.00           1.0        1.0
# 37975                    0.3         48.55           1.0        1.0
#
#        congestion_surcharge
# 27497                   0.0
# ...

# %%
jan_fhv_zones = jan_fhv[jan_fhv['PUlocationID' or 'DOlocationID' ].isin([186,164,100])]
jan_fhv_zones
# Out:
#         dispatching_base_num     pickup_datetime    dropOff_datetime  \
# 765                   B03160 2022-01-01 00:11:00 2022-01-01 00:19:00
# 787                   B03160 2022-01-01 00:52:00 2022-01-01 01:01:00
# 796                   B03160 2022-01-01 00:12:00 2022-01-01 00:24:00
# 1120                  B01087 2022-01-01 01:46:43 2022-01-01 02:11:12
# 1641                  B03160 2022-01-01 01:46:00 2022-01-01 01:55:00
# ...                      ...                 ...                 ...
# 1142876               B03380 2022-01-31 22:42:57 2022-01-31 23:02:55
# 1142894               B03380 2022-01-31 22:57:01 2022-01-31 23:04:55
# 1142895               B03380 2022-01-31 22:06:03 2022-01-31 22:17:57
# 1143662               B03284 2022-01-31 23:31:33 2022-02-01 00:09:03
# 1143679               B03380 2022-01-31 23:31:49 2022-01-31 23:43:06
#
#          PUlocationID  DOlocationID  SR_Flag Affiliated_base_number
# 765             164.0         100.0      NaN                 B03404
# ...

# %%
jan_fhvhv_zones = jan_fhvhv[jan_fhvhv['PULocationID' or 'DOLcationID' ].isin([186,164,100])]
jan_fhvhv_zones
# Out:
#          hvfhs_license_num dispatching_base_num originating_base_num  \
# 57                  HV0003               B03404               B03404
# 157                 HV0003               B03404               B03404
# 166                 HV0003               B03404               B03404
# 220                 HV0003               B03404               B03404
# 254                 HV0005               B03406                 None
# ...                    ...                  ...                  ...
# 14751441            HV0003               B03404               B03404
# 14751468            HV0003               B03404               B03404
# 14751469            HV0003               B03404               B03404
# 14751567            HV0003               B03404               B03404
# 14751571            HV0003               B03404               B03404
#
#             request_datetime   on_scene_datetime     pickup_datetime  \
# ...
